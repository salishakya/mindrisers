# %%
# Activity_ Course 4 Automatidata project lab

from numpy import dtype
import pandas as pd
from scipy import stats

# %%
taxi_data = pd.read_csv("../csv/2017_Yellow_Taxi_Trip_Data.csv", index_col=0)

# %%
taxi_data.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  22699.000000     22699.000000   22699.000000  22699.000000
# mean       1.556236         1.642319       2.913313      1.043394
# std        0.496838         1.285231       3.653171      0.708391
# min        1.000000         0.000000       0.000000      1.000000
# 25%        1.000000         1.000000       0.990000      1.000000
# 50%        2.000000         1.000000       1.610000      1.000000
# 75%        2.000000         2.000000       3.060000      1.000000
# max        2.000000         6.000000      33.960000     99.000000
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean     162.412353    161.527997      1.336887     13.026629      0.333275
# std       66.633373     70.139691      0.496211     13.243791      0.463097
# min        1.000000      1.000000      1.000000   -120.000000     -1.000000
# 25%      114.000000    112.000000      1.000000      6.500000      0.000000
# 50%      162.000000    162.000000      1.000000      9.500000      0.000000
# 75%      233.000000    233.000000      2.000000     14.500000      0.500000
# max      265.000000    265.000000      4.000000    999.990000      4.500000
#
#             mta_tax    tip_amount  tolls_amount  improvement_surcharge  \
# count  22699.000000  22699.000000  22699.000000           22699.000000
# mean       0.497445      1.835781      0.312542               0.299551
# std        0.039465      2.800626      1.399212               0.015673
# min       -0.500000      0.000000      0.000000              -0.300000
# 25%        0.500000      0.000000      0.000000               0.300000
# 50%        0.500000      1.350000      0.000000               0.300000
# 75%        0.500000      2.450000      0.000000               0.300000
# max        0.500000    200.000000     19.100000               0.300000
#
#        total_amount
# count  22699.000000
# mean      16.310502
# std       16.097295
# min     -120.300000
# 25%        8.750000
# 50%       11.800000
# 75%       17.800000
# max     1200.290000

# %%
taxi_data.head()
# Out:
#            VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 24870114          2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 35634249          1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 38942136          2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 30841670          2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
#
#            passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 24870114                 6           3.34           1                  N
# 35634249                 1           1.80           1                  N
# 106203690                1           1.00           1                  N
# 38942136                 1           3.70           1                  N
# 30841670                 1           4.37           1                  N
#
#            PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# 24870114            100           231             1         13.0    0.0
# 35634249            186            43             1         16.0    0.0
# 106203690           262           236             1          6.5    0.0
# 38942136            188            97             1         20.5    0.0
# 30841670              4           112             2         16.5    0.5
#
#            mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 24870114       0.5        2.76           0.0                    0.3
# 35634249       0.5        4.00           0.0                    0.3
# 106203690      0.5        1.45           0.0                    0.3
# 38942136       0.5        6.39           0.0                    0.3
# 30841670       0.5        0.00           0.0                    0.3
#
#            total_amount
# 24870114          16.56
# 35634249          20.80
# 106203690          8.75
# 38942136          27.69
# 30841670          17.80

# %%
taxi_data.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount'],
#       dtype='object')

# %%
# In the dataset, payment_type is encoded in integers: * 1: Credit card * 2: Cash * 3: No
# charge * 4: Dispute * 5: Unknown

print(taxi_data["payment_type"].unique())
# Out:
# [1 2 3 4]

# %%
# Hypothesis testing

# H0: There is no difference in the average fare amount between customers who use credit cards and
# customers who use cash.
# HA: There is a difference in the average fare amount between customers who use credit cards and
# customers who use cash.

# %%
dtype(taxi_data["payment_type"])
# Out:
# dtype('int64')

# %%
customers_cc = taxi_data[taxi_data["payment_type"] == 1]
customers_cc.head()
# Out:
#            VendorID   tpep_pickup_datetime  tpep_dropoff_datetime  \
# 24870114          2  03/25/2017 8:55:43 AM  03/25/2017 9:09:47 AM
# 35634249          1  04/11/2017 2:53:28 PM  04/11/2017 3:19:58 PM
# 106203690         1  12/15/2017 7:26:56 AM  12/15/2017 7:34:08 AM
# 38942136          2  05/07/2017 1:17:59 PM  05/07/2017 1:48:14 PM
# 23345809          2  03/25/2017 8:34:11 PM  03/25/2017 8:42:11 PM
#
#            passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 24870114                 6           3.34           1                  N
# 35634249                 1           1.80           1                  N
# 106203690                1           1.00           1                  N
# 38942136                 1           3.70           1                  N
# 23345809                 6           2.30           1                  N
#
#            PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# 24870114            100           231             1         13.0    0.0
# 35634249            186            43             1         16.0    0.0
# 106203690           262           236             1          6.5    0.0
# 38942136            188            97             1         20.5    0.0
# 23345809            161           236             1          9.0    0.5
#
#            mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 24870114       0.5        2.76           0.0                    0.3
# 35634249       0.5        4.00           0.0                    0.3
# 106203690      0.5        1.45           0.0                    0.3
# 38942136       0.5        6.39           0.0                    0.3
# 23345809       0.5        2.06           0.0                    0.3
#
#            total_amount
# 24870114          16.56
# 35634249          20.80
# 106203690          8.75
# 38942136          27.69
# 23345809          12.36

# %%
customers_cash = taxi_data[taxi_data["payment_type"] == 2]
customers_cash.head()
# Out:
#            VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 30841670          2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# 8433159           2   02/04/2017 4:17:07 PM   02/04/2017 4:29:14 PM
# 35388828          2   04/10/2017 6:12:58 PM   04/10/2017 6:17:39 PM
# 110690689         1  12/30/2017 11:52:44 PM  12/30/2017 11:58:57 PM
# 99525452          2  11/24/2017 10:48:13 AM  11/24/2017 10:52:57 AM
#
#            passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 30841670                 1           4.37           1                  N
# 8433159                  1           1.20           1                  N
# 35388828                 2           0.63           1                  N
# 110690689                1           1.10           1                  N
# 99525452                 1           0.85           1                  N
#
#            PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# 30841670              4           112             2         16.5    0.5
# 8433159             234           249             2          9.0    0.0
# 35388828            263           262             2          5.0    1.0
# 110690689           166           238             2          6.5    0.5
# 99525452            237           161             2          5.5    0.0
#
#            mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 30841670       0.5         0.0           0.0                    0.3
# 8433159        0.5         0.0           0.0                    0.3
# 35388828       0.5         0.0           0.0                    0.3
# 110690689      0.5         0.0           0.0                    0.3
# 99525452       0.5         0.0           0.0                    0.3
#
#            total_amount
# 30841670           17.8
# 8433159             9.8
# 35388828            6.8
# 110690689           7.8
# 99525452            6.3

# %%
sample_customer_cc = customers_cc.sample(n=50, replace=True, random_state=42)
sample_customer_cash = customers_cash.sample(n=50, replace=True, random_state=42)

# %%
sample_customer_cc.head()
# Out:
#           VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 51381734         1   06/17/2017 2:40:51 PM   06/17/2017 3:11:46 PM
# 38996612         2   05/07/2017 4:11:56 PM   05/07/2017 5:05:06 PM
# 67660271         2  08/10/2017 10:21:37 AM  08/10/2017 10:26:19 AM
# 89909636         1   10/25/2017 7:09:18 AM   10/25/2017 7:17:15 AM
# 36040242         2   04/12/2017 4:23:50 PM   04/12/2017 4:43:25 PM
#
#           passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 51381734                1           2.70           1                  N
# 38996612                1           3.99           1                  N
# 67660271                1           1.11           1                  N
# 89909636                1           1.60           1                  N
# 36040242                1           1.38           1                  N
#
#           PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# 51381734           144           186             1         19.0    0.0
# 38996612           255           249             1         30.5    0.0
# 67660271           166           238             1          6.0    0.0
# 89909636           162           140             1          8.0    0.0
# 36040242           161           164             1         12.5    1.0
#
#           mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 51381734      0.5        3.95           0.0                    0.3
# 38996612      0.5        5.00           0.0                    0.3
# 67660271      0.5        2.04           0.0                    0.3
# 89909636      0.5        1.76           0.0                    0.3
# 36040242      0.5        4.29           0.0                    0.3
#
#           total_amount
# 51381734         23.75
# 38996612         36.30
# 67660271          8.84
# 89909636         10.56
# 36040242         18.59

# %%
sample_customer_cash.head()
# Out:
#            VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 45838957          1   05/28/2017 4:47:27 PM   05/28/2017 4:56:29 PM
# 104666033         2   12/10/2017 2:50:49 PM   12/10/2017 2:55:55 PM
# 59257905          2  07/12/2017 11:38:53 AM  07/12/2017 11:52:05 AM
# 99883301          2   11/25/2017 7:16:32 PM   11/25/2017 7:31:16 PM
# 26362083          2  03/31/2017 10:47:12 AM  03/31/2017 11:07:15 AM
#
#            passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 45838957                 3           2.00           1                  N
# 104666033                1           1.01           1                  N
# 59257905                 6           1.46           1                  N
# 99883301                 1           2.20           1                  N
# 26362083                 2           2.82           1                  N
#
#            PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# 45838957             48            68             2          8.5    0.0
# 104666033           239           238             2          5.5    0.0
# 59257905            239           142             2         10.0    0.0
# 99883301            170           236             2         11.0    0.0
# 26362083            164           140             2         14.5    0.0
#
#            mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 45838957       0.5         0.0           0.0                    0.3
# 104666033      0.5         0.0           0.0                    0.3
# 59257905       0.5         0.0           0.0                    0.3
# 99883301       0.5         0.0           0.0                    0.3
# 26362083       0.5         0.0           0.0                    0.3
#
#            total_amount
# 45838957            9.3
# 104666033           6.3
# 59257905           10.8
# 99883301           11.8
# 26362083           15.3

# %%
ab_test = stats.ttest_ind(
    a=sample_customer_cc["payment_type"],
    b=sample_customer_cash["payment_type"],
    equal_var=False,
)
# Out:
# c:\Users\salis\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
sample_customer_cc.head()
# Out:
#           VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 51381734         1   06/17/2017 2:40:51 PM   06/17/2017 3:11:46 PM
# 38996612         2   05/07/2017 4:11:56 PM   05/07/2017 5:05:06 PM
# 67660271         2  08/10/2017 10:21:37 AM  08/10/2017 10:26:19 AM
# 89909636         1   10/25/2017 7:09:18 AM   10/25/2017 7:17:15 AM
# 36040242         2   04/12/2017 4:23:50 PM   04/12/2017 4:43:25 PM
#
#           passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 51381734                1           2.70           1                  N
# 38996612                1           3.99           1                  N
# 67660271                1           1.11           1                  N
# 89909636                1           1.60           1                  N
# 36040242                1           1.38           1                  N
#
#           PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# 51381734           144           186             1         19.0    0.0
# 38996612           255           249             1         30.5    0.0
# 67660271           166           238             1          6.0    0.0
# 89909636           162           140             1          8.0    0.0
# 36040242           161           164             1         12.5    1.0
#
#           mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 51381734      0.5        3.95           0.0                    0.3
# 38996612      0.5        5.00           0.0                    0.3
# 67660271      0.5        2.04           0.0                    0.3
# 89909636      0.5        1.76           0.0                    0.3
# 36040242      0.5        4.29           0.0                    0.3
#
#           total_amount
# 51381734         23.75
# 38996612         36.30
# 67660271          8.84
# 89909636         10.56
# 36040242         18.59

# %%
sample_customer_cash.head()
# Out:
#            VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 45838957          1   05/28/2017 4:47:27 PM   05/28/2017 4:56:29 PM
# 104666033         2   12/10/2017 2:50:49 PM   12/10/2017 2:55:55 PM
# 59257905          2  07/12/2017 11:38:53 AM  07/12/2017 11:52:05 AM
# 99883301          2   11/25/2017 7:16:32 PM   11/25/2017 7:31:16 PM
# 26362083          2  03/31/2017 10:47:12 AM  03/31/2017 11:07:15 AM
#
#            passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 45838957                 3           2.00           1                  N
# 104666033                1           1.01           1                  N
# 59257905                 6           1.46           1                  N
# 99883301                 1           2.20           1                  N
# 26362083                 2           2.82           1                  N
#
#            PULocationID  DOLocationID  payment_type  fare_amount  extra  \
# 45838957             48            68             2          8.5    0.0
# 104666033           239           238             2          5.5    0.0
# 59257905            239           142             2         10.0    0.0
# 99883301            170           236             2         11.0    0.0
# 26362083            164           140             2         14.5    0.0
#
#            mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 45838957       0.5         0.0           0.0                    0.3
# 104666033      0.5         0.0           0.0                    0.3
# 59257905       0.5         0.0           0.0                    0.3
# 99883301       0.5         0.0           0.0                    0.3
# 26362083       0.5         0.0           0.0                    0.3
#
#            total_amount
# 45838957            9.3
# 104666033           6.3
# 59257905           10.8
# 99883301           11.8
# 26362083           15.3

# %%
stats.ttest_ind(
    a=sample_customer_cc["payment_type"],
    b=sample_customer_cash["payment_type"],
    equal_var=False,
)
# Out:
# c:\Users\salis\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# TtestResult(statistic=np.float64(-inf), pvalue=np.float64(0.0), df=np.float64(1.0))

# %%
sample_customer_cc.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount'],
#       dtype='object')

# %%
ab_test = stats.ttest_ind(
    a=sample_customer_cc["fare_amount"],
    b=sample_customer_cash["fare_amount"],
    equal_var=False,
)

# %%
ab_test
# Out:
# TtestResult(statistic=np.float64(0.24651381588498536), pvalue=np.float64(0.805804003364833), df=np.float64(97.26934552287736))

# %%
# here the p value is 0.80 i.e. more than 0.05 significance value so we fail to reject the null hypothesis.
